# %%
def function(a,n):
  even=0
  odd=1
  for i in range(n):
    if i%2==0:
      even +=a[i]
    else:
      odd *=a[i]
  print ("Even index position sum",even)
  print ("Odd index position multip",odd)
my_list = [1, 2, 3, 4, 5, 6] 
n = len(my_list) 
  
function(my_list, n)
# Out:
# Even index position sum 9
# Odd index position multip 48
